# %%
# %pip install dbt-duckdb
# %pip install pandas
# Out:
# Requirement already satisfied: dbt-duckdb in /opt/homebrew/lib/python3.10/site-packages (1.9.1)
# Requirement already satisfied: dbt-common<2,>=1 in /opt/homebrew/lib/python3.10/site-packages (from dbt-duckdb) (1.14.0)
# Requirement already satisfied: dbt-adapters<2,>=1 in /opt/homebrew/lib/python3.10/site-packages (from dbt-duckdb) (1.14.0)
# Requirement already satisfied: duckdb>=1.0.0 in /opt/homebrew/lib/python3.10/site-packages (from dbt-duckdb) (1.2.0)
# Requirement already satisfied: dbt-core>=1.8.0 in /opt/homebrew/lib/python3.10/site-packages (from dbt-duckdb) (1.9.2)
# Requirement already satisfied: agate<2.0,>=1.0 in /opt/homebrew/lib/python3.10/site-packages (from dbt-adapters<2,>=1->dbt-duckdb) (1.9.1)
# Requirement already satisfied: mashumaro<3.15,>=3.9 in /opt/homebrew/lib/python3.10/site-packages (from mashumaro[msgpack]<3.15,>=3.9->dbt-adapters<2,>=1->dbt-duckdb) (3.14)
# Requirement already satisfied: protobuf<6.0,>=5.0 in /opt/homebrew/lib/python3.10/site-packages (from dbt-adapters<2,>=1->dbt-duckdb) (5.29.3)
# Requirement already satisfied: pytz>=2015.7 in /opt/homebrew/lib/python3.10/site-packages (from dbt-adapters<2,>=1->dbt-duckdb) (2025.1)
# Requirement already satisfied: typing-extensions<5.0,>=4.0 in /Users/takeshiiijima/Library/Python/3.10/lib/python/site-packages (from dbt-adapters<2,>=1->dbt-duckdb) (4.12.2)
# Requirement already satisfied: colorama<0.5,>=0.3.9 in /opt/homebrew/lib/python3.10/site-packages (from dbt-common<2,>=1->dbt-duckdb) (0.4.6)
# Requirement already satisfied: deepdiff<8.0,>=7.0 in /opt/homebrew/lib/python3.10/site-packages (from dbt-common<2,>=1->dbt-duckdb) (7.0.1)
# Requirement already satisfied: isodate<0.7,>=0.6 in /opt/homebrew/lib/python3.10/site-packages (from dbt-common<2,>=1->dbt-duckdb) (0.6.1)
# Requirement already satisfied: jinja2<4,>=3.1.3 in /opt/homebrew/lib/python3.10/site-packages (from dbt-common<2,>=1->dbt-duckdb) (3.1.5)
# Requirement already satisfied: jsonschema<5.0,>=4.0 in /opt/homebrew/lib/python3.10/site-packages (from dbt-common<2,>=1->dbt-duckdb) (4.23.0)
# Requirement already satisfied: pathspec<0.13,>=0.9 in /opt/homebrew/lib/python3.10/site-packages (from dbt-common<2,>=1->dbt-duckdb) (0.12.1)
# Requirement already satisfied: python-dateutil<3.0,>=2.0 in /Users/takeshiiijima/Library/Python/3.10/lib/python/site-packages (from dbt-common<2,>=1->dbt-duckdb) (2.9.0.post0)
# Requirement already satisfied: requests<3.0.0 in /opt/homebrew/lib/python3.10/site-packages (from dbt-common<2,>=1->dbt-duckdb) (2.32.3)
# Requirement already satisfied: click<9.0,>=8.0.2 in /opt/homebrew/lib/python3.10/site-packages (from dbt-core>=1.8.0->dbt-duckdb) (8.1.8)
# Requirement already satisfied: networkx<4.0,>=2.3 in /opt/homebrew/lib/python3.10/site-packages (from dbt-core>=1.8.0->dbt-duckdb) (3.4.2)
# Requirement already satisfied: snowplow-tracker<2.0,>=1.0.2 in /opt/homebrew/lib/python3.10/site-packages (from dbt-core>=1.8.0->dbt-duckdb) (1.0.4)
# Requirement already satisfied: sqlparse<0.6.0,>=0.5.0 in /opt/homebrew/lib/python3.10/site-packages (from dbt-core>=1.8.0->dbt-duckdb) (0.5.3)
# Requirement already satisfied: dbt-extractor<=0.6,>=0.5.0 in /opt/homebrew/lib/python3.10/site-packages (from dbt-core>=1.8.0->dbt-duckdb) (0.5.1)
# Requirement already satisfied: dbt-semantic-interfaces<0.8,>=0.7.4 in /opt/homebrew/lib/python3.10/site-packages (from dbt-core>=1.8.0->dbt-duckdb) (0.7.4)
# Requirement already satisfied: packaging>20.9 in /Users/takeshiiijima/Library/Python/3.10/lib/python/site-packages (from dbt-core>=1.8.0->dbt-duckdb) (24.2)
# Requirement already satisfied: pyyaml>=6.0 in /opt/homebrew/lib/python3.10/site-packages (from dbt-core>=1.8.0->dbt-duckdb) (6.0.2)
# Requirement already satisfied: daff>=1.3.46 in /opt/homebrew/lib/python3.10/site-packages (from dbt-core>=1.8.0->dbt-duckdb) (1.3.46)
# Requirement already satisfied: Babel>=2.0 in /opt/homebrew/lib/python3.10/site-packages (from agate<2.0,>=1.0->dbt-adapters<2,>=1->dbt-duckdb) (2.17.0)
# Requirement already satisfied: leather>=0.3.2 in /opt/homebrew/lib/python3.10/site-packages (from agate<2.0,>=1.0->dbt-adapters<2,>=1->dbt-duckdb) (0.4.0)
# Requirement already satisfied: parsedatetime!=2.5,>=2.1 in /opt/homebrew/lib/python3.10/site-packages (from agate<2.0,>=1.0->dbt-adapters<2,>=1->dbt-duckdb) (2.6)
# Requirement already satisfied: python-slugify>=1.2.1 in /opt/homebrew/lib/python3.10/site-packages (from agate<2.0,>=1.0->dbt-adapters<2,>=1->dbt-duckdb) (8.0.4)
# Requirement already satisfied: pytimeparse>=1.1.5 in /opt/homebrew/lib/python3.10/site-packages (from agate<2.0,>=1.0->dbt-adapters<2,>=1->dbt-duckdb) (1.1.8)
# Requirement already satisfied: importlib-metadata<7,>=6.0 in /opt/homebrew/lib/python3.10/site-packages (from dbt-semantic-interfaces<0.8,>=0.7.4->dbt-core>=1.8.0->dbt-duckdb) (6.11.0)
# Requirement already satisfied: more-itertools<11.0,>=8.0 in /opt/homebrew/lib/python3.10/site-packages (from dbt-semantic-interfaces<0.8,>=0.7.4->dbt-core>=1.8.0->dbt-duckdb) (10.6.0)
# Requirement already satisfied: pydantic<3,>=1.10 in /opt/homebrew/lib/python3.10/site-packages (from dbt-semantic-interfaces<0.8,>=0.7.4->dbt-core>=1.8.0->dbt-duckdb) (2.10.6)
# Requirement already satisfied: ordered-set<4.2.0,>=4.1.0 in /opt/homebrew/lib/python3.10/site-packages (from deepdiff<8.0,>=7.0->dbt-common<2,>=1->dbt-duckdb) (4.1.0)
# Requirement already satisfied: six in /Users/takeshiiijima/Library/Python/3.10/lib/python/site-packages (from isodate<0.7,>=0.6->dbt-common<2,>=1->dbt-duckdb) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/lib/python3.10/site-packages (from jinja2<4,>=3.1.3->dbt-common<2,>=1->dbt-duckdb) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /opt/homebrew/lib/python3.10/site-packages (from jsonschema<5.0,>=4.0->dbt-common<2,>=1->dbt-duckdb) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/homebrew/lib/python3.10/site-packages (from jsonschema<5.0,>=4.0->dbt-common<2,>=1->dbt-duckdb) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/homebrew/lib/python3.10/site-packages (from jsonschema<5.0,>=4.0->dbt-common<2,>=1->dbt-duckdb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/homebrew/lib/python3.10/site-packages (from jsonschema<5.0,>=4.0->dbt-common<2,>=1->dbt-duckdb) (0.22.3)
# Requirement already satisfied: msgpack>=0.5.6 in /opt/homebrew/lib/python3.10/site-packages (from mashumaro[msgpack]<3.15,>=3.9->dbt-adapters<2,>=1->dbt-duckdb) (1.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.10/site-packages (from requests<3.0.0->dbt-common<2,>=1->dbt-duckdb) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.10/site-packages (from requests<3.0.0->dbt-common<2,>=1->dbt-duckdb) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/lib/python3.10/site-packages (from requests<3.0.0->dbt-common<2,>=1->dbt-duckdb) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.10/site-packages (from requests<3.0.0->dbt-common<2,>=1->dbt-duckdb) (2025.1.31)
# Requirement already satisfied: types-requests<3.0,>=2.25.1 in /opt/homebrew/lib/python3.10/site-packages (from snowplow-tracker<2.0,>=1.0.2->dbt-core>=1.8.0->dbt-duckdb) (2.32.0.20241016)
# Requirement already satisfied: zipp>=0.5 in /opt/homebrew/lib/python3.10/site-packages (from importlib-metadata<7,>=6.0->dbt-semantic-interfaces<0.8,>=0.7.4->dbt-core>=1.8.0->dbt-duckdb) (3.21.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/homebrew/lib/python3.10/site-packages (from pydantic<3,>=1.10->dbt-semantic-interfaces<0.8,>=0.7.4->dbt-core>=1.8.0->dbt-duckdb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /opt/homebrew/lib/python3.10/site-packages (from pydantic<3,>=1.10->dbt-semantic-interfaces<0.8,>=0.7.4->dbt-core>=1.8.0->dbt-duckdb) (2.27.2)
# Requirement already satisfied: text-unidecode>=1.3 in /opt/homebrew/lib/python3.10/site-packages (from python-slugify>=1.2.1->agate<2.0,>=1.0->dbt-adapters<2,>=1->dbt-duckdb) (1.3)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting pandas
#   Downloading pandas-2.2.3-cp310-cp310-macosx_11_0_arm64.whl.metadata (89 kB)
# Collecting numpy>=1.22.4 (from pandas)
#   Downloading numpy-2.2.2-cp310-cp310-macosx_14_0_arm64.whl.metadata (62 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/takeshiiijima/Library/Python/3.10/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.10/site-packages (from pandas) (2025.1)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /Users/takeshiiijima/Library/Python/3.10/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.2.3-cp310-cp310-macosx_11_0_arm64.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 9.9 MB/s eta 0:00:00ta 0:00:01
# Downloading numpy-2.2.2-cp310-cp310-macosx_14_0_arm64.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 9.6 MB/s eta 0:00:00ta 0:00:01
# Downloading tzdata-2025.1-py2.py3-none-any.whl (346 kB)
# Installing collected packages: tzdata, numpy, pandas
# Successfully installed numpy-2.2.2 pandas-2.2.3 tzdata-2025.1
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import duckdb
import pandas as pd

# DuckDB データベースファイルに接続
con = duckdb.connect('duckdb.db')

# star_schema_view テーブルの先頭 10 行を DataFrame として取得
df = con.execute('SELECT * FROM star_schema_view LIMIT 10').df()

# DataFrame を表示
df
# Out:
#    sale_id  quantity  total_amount  customer_id customer_name customer_city  \
# 0        1         2         39.98            1      John Doe      New York
# 1        2         1         29.99            2    Jane Smith   Los Angeles
# 2        3         3        119.97            3   Bob Johnson       Chicago
#
#   customer_state  product_id product_name product_category  price  date_key  \
# 0             NY           1     Widget A          Gadgets  19.99  20220101
# 1             CA           2     Widget B          Gadgets  29.99  20220102
# 2             IL           3     Widget C          Gadgets  39.99  20220103
#
#         date  year  month  day
# 0 2022-01-01  2022      1    1
# 1 2022-01-02  2022      1    2
# 2 2022-01-03  2022      1    3
